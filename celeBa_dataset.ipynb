# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
DATA_PATH = 'data/celeba'
DATA_LIST = glob.glob(DATA_PATH+'/*.jpg')

# %%
img_list = np.array(DATA_LIST)
print(img_list.shape)
#img_list = img_list[:200000]
#print(img_list.shape)
#img_list = img_list.reshape((10, 20000))
#print(img_list.shape)
# Out:
# (202599,)

# %%
img = Image.open(img_list[2])
plt.imshow(img)
plt.show()
print(np.array(img).shape)
# Out:
# (218, 178, 3)

# %%
from PIL import Image

nr_img_list = []
for i in range(50):
    if i % 10000 ==0: 
        print(i)
    img = Image.open(img_list[i])
    img = img.resize((128,128))
    img = np.array(img)
    img = img/255
    nr_img_list.append(img)
# Out:
# 0

# %%
plt.imshow(nr_img_list[3])

# %%
x_data = np.array(nr_img_list)
x_data.shape
# Out:
# (50000, 108, 88, 3)

# %%
np.save('data/x_data_5000', x_data)
